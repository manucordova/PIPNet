# %%
import numpy as np
import os
import sys
import copy

import torch
torch.set_num_threads(os.cpu_count())
from torch import nn

import pickle as pk

import matplotlib as mpl
import matplotlib.pyplot as plt

from pipnet import data
from pipnet import model
from pipnet import utils

device = "cuda" if torch.cuda.is_available() else "cpu"

np.random.seed(1)

# %%
#comparison = "layers"
#comparison = "kernel_size"
#comparison = "output_kernel_size"
#comparison = "n_batch"
comparison = "encoding"

if comparison == "layers":
    
    mods = [
        "PIPNet_2022_09_28_2_layers",
        "PIPNet_2022_09_28_3_layers",
        "PIPNet_2022_09_28_4_layers",
        "PIPNet_2022_09_28_5_layers",
#        "PIPNet_2022_09_28_6_layers",
        "PIPNet_2022_10_03_batch_4",
#        "PIPNet_2022_09_28_7_layers",
#        "PIPNet_2022_09_28_8_layers",
    ]


    labels = ["2 layers", "3 layers", "4 layers", "5 layers", "6 layers", "7 layers", "8 layers"]

elif comparison == "kernel_size":
    
    mods = [
        "PIPNet_2022_09_30_k_1",
        "PIPNet_2022_09_30_k_3",
        "PIPNet_2022_09_30_k_5",
        "PIPNet_2022_09_30_k_7",
        "PIPNet_2022_09_30_k_9",
        "PIPNet_2022_09_30_k_11",
        "PIPNet_2022_09_30_k_13",
        "PIPNet_2022_09_30_k_15",
    ]


    labels = ["k = 1", "k = 3", "k = 5", "k = 7", "k = 9", "k = 11", "k = 13", "k = 15"]

elif comparison == "output_kernel_size":
    
    mods = [
        "PIPNet_2022_09_30_output_k_1",
        "PIPNet_2022_09_30_output_k_3",
        "PIPNet_2022_09_30_output_k_5",
        "PIPNet_2022_09_30_output_k_7",
        "PIPNet_2022_09_30_output_k_9",
    ]


    labels = ["k = 1", "k = 3", "k = 5", "k = 7", "k = 9"]

elif comparison == "n_batch":
    
    mods = [
        "PIPNet_2022_10_03_batch_1",
        "PIPNet_2022_10_03_batch_2",
        "PIPNet_2022_10_03_batch_3",
        "PIPNet_2022_10_03_batch_4",
        "PIPNet_2022_10_03_batch_5",
        "PIPNet_2022_10_03_batch_6",
    ]


    labels = ["1", "2", "3", "4", "5", "6"]

elif comparison == "encoding":
    
    mods = [
        "PIPNet_2022_10_03_batch_4",
#        "PIPNet_2022_10_03_imag",
        "PIPNet_2022_10_03_output_gate",
        "PIPNet_2022_10_03_wr_inv",
        "PIPNet_2022_10_03_mas_shifts",
    ]


    labels = [
        "Baseline",
#        "Imaginary",
        "Output gate",
        "Inverse wr",
        "MAS shifts",
    ]

else:
    raise ValueError(f"Unknown comparison: {comparison}")
    
in_root = f"../../figures/1D/"

fig_dir = f"../../figures/1D/compare_{comparison}/"

if not os.path.exists(fig_dir):
    os.mkdir(fig_dir)

# %%
evaluations = []
evaluation_keys = {}
for mod in mods:
    
    mod_evaluations = {}
    
    print(f"Loading {mod}")
    
    for f in os.listdir(f"{in_root}{mod}/evaluation/"):
        if f.startswith("eval_") and f.endswith(".txt"):
            with open(f"{in_root}{mod}/evaluation/{f}", "r") as F:
                lines = F.read().split("\n")
            
            ev = f.split("eval_")[1].split(".txt")[0]
            
            mod_evaluations[ev] = []
            evaluation_keys[ev] = []
            for l in lines:
                if len(l) > 0:
                    tmp = l.split()
                    try:
                        evaluation_keys[ev].append(float(tmp[0]))
                    except:
                        evaluation_keys[ev].append(tmp[0])
                    
                    mod_evaluations[ev].append(list(map(float, tmp[1:])))
            
            mod_evaluations[ev] = np.array(mod_evaluations[ev])
            
    evaluations.append(mod_evaluations)
# Out:
# Loading PIPNet_2022_10_03_batch_4
# Loading PIPNet_2022_10_03_output_gate
# Loading PIPNet_2022_10_03_wr_inv
# Loading PIPNet_2022_10_03_mas_shifts

# %%
for k in evaluation_keys:
    
    fig = plt.figure(figsize=(8,6))
    ax1 = fig.add_subplot(2,2,1)
    ax2 = fig.add_subplot(2,2,2)
    ax3 = fig.add_subplot(2,2,3)
    ax4 = fig.add_subplot(2,2,4)

    fig2 = plt.figure(figsize=(8,6))
    ax12 = fig2.add_subplot(2,2,1)
    ax22 = fig2.add_subplot(2,2,2)
    ax32 = fig2.add_subplot(2,2,3)
    ax42 = fig2.add_subplot(2,2,4)
    
    max_errs = [0., 0., 0., 0.]
    max_errs_norm = [0., 0., 0., 0.]
    for i, ev in enumerate(evaluations):
        ax1.plot(evaluation_keys[k], ev[k][:, 0], f"C{i}.-")
        ax2.plot(evaluation_keys[k], ev[k][:, 1], f"C{i}.-")
        ax3.plot(evaluation_keys[k], ev[k][:, 2], f"C{i}.-")
        ax4.plot(evaluation_keys[k], ev[k][:, 3], f"C{i}.-")
        
        m = np.max(ev[k][:, :4], axis=0)
        max_errs[0] = max(max_errs[0], m[0])
        max_errs[1] = max(max_errs[1], m[1])
        max_errs[2] = max(max_errs[2], m[2])
        max_errs[3] = max(max_errs[3], m[3])
                
        if ev[k].shape[1] > 4:
            ax12.plot(evaluation_keys[k], ev[k][:, 4], f"C{i}.-")
            ax22.plot(evaluation_keys[k], ev[k][:, 5], f"C{i}.-")
            ax32.plot(evaluation_keys[k], ev[k][:, 6], f"C{i}.-")
            ax42.plot(evaluation_keys[k], ev[k][:, 7], f"C{i}.-")
        
            m = np.max(ev[k][:, 4:], axis=0)
            max_errs_norm[0] = max(max_errs_norm[0], m[0])
            max_errs_norm[1] = max(max_errs_norm[1], m[1])
            max_errs_norm[2] = max(max_errs_norm[2], m[2])
            max_errs_norm[3] = max(max_errs_norm[3], m[3])
            
    ax1.set_ylabel("Spectrum MAE")
    ax2.set_ylabel("Integral MAE")
    ax3.set_ylabel("Spectrum MSE")
    ax4.set_ylabel("Cosine similarity")
    
    ax1.set_xlabel(f"{k}")
    ax2.set_xlabel(f"{k}")
    ax3.set_xlabel(f"{k}")
    ax4.set_xlabel(f"{k}")
    
    if k == "noise" or k == "lw_noise":
        ax1.set_xscale("log")
        ax2.set_xscale("log")
        ax3.set_xscale("log")
        ax4.set_xscale("log")
    
    ax1.set_ylim(0., max_errs[0] * 1.1)
    ax2.set_ylim(0., max_errs[1] * 1.1)
    ax3.set_ylim(0., max_errs[2] * 1.1)
    ax4.set_ylim(0., max_errs[3] * 1.1)
    
    ax2.legend(labels)
    
    fig.tight_layout()
    fig.savefig(f"{fig_dir}compare_{k}.pdf")
    plt.close(fig) 
        
    if ev[k].shape[1] > 4:
        ax12.set_ylabel("Spectrum MAE")
        ax22.set_ylabel("Integral MAE")
        ax32.set_ylabel("Spectrum MSE")
        ax42.set_ylabel("Cosine similarity")

        ax12.set_xlabel(f"{k}")
        ax22.set_xlabel(f"{k}")
        ax32.set_xlabel(f"{k}")
        ax42.set_xlabel(f"{k}")
    
        ax12.set_ylim(0., max_errs_norm[0] * 1.1)
        ax22.set_ylim(0., max_errs_norm[1] * 1.1)
        ax32.set_ylim(0., max_errs_norm[2] * 1.1)
        ax42.set_ylim(0., max_errs_norm[3] * 1.1)

        ax22.legend(labels)

        fig2.tight_layout()
        fig2.savefig(f"{fig_dir}compare_{k}_norm.pdf")

    plt.close(fig2)
