# %%
import numpy as np
import os
import json
import torch

from pipnet import data
from pipnet import model
from pipnet import train

torch.set_num_threads(os.cpu_count())
device = "cuda" if torch.cuda.is_available() else "cpu"

import matplotlib.pyplot as plt
from IPython import display

np.random.seed(1)

# %% [markdown]
# # Define data generation parameters

# %%
iso_pars = dict(
    td = 128,
    Fs = 3_200,
    nmin = 1,
    nmax = 5,
    freq_range = [500., 2700.],
    gmin = 1,
    gmax = 1,
    spread = 5.,
    lw_range = [[5e1, 2e2], [1e2, 5e2], [1e2, 1e3]],
    lw_probs = [0.7, 0.2, 0.1],
    int_range = [0.5, 1.], # Intensity
    phase = 0.,
    debug = False,
)

mas_pars = dict(
    nw = 12,
    mas_w_range = [50_000., 100_000.],
    random_mas = True,
    mas_phase_p = 0.5,
    mas_phase_scale = 0.05,
    
    # First-order MAS-dependent parameters
    mas1_lw_range = [[1e7, 5e7], [5e7, 1e8]],
    mas1_lw_probs = [0.8, 0.2],
    mas1_m_range = [[0., 0.], [0., 1e4], [1e4, 5e4]],
    mas1_m_probs = [0.1, 0.1, 0.8],
    mas1_s_range = [[-1e7, 1e7]],
    mas1_s_probs = [1.],

    # Second-order MAS-dependent parameters
    mas2_prob = 1.,
    mas2_lw_range = [[0., 0.], [1e11, 5e11]],
    mas2_lw_probs = [0.5, 0.5],
    mas2_m_range = [[0., 0.], [1e8, 5e8]],
    mas2_m_probs = [0.8, 0.2],
    mas2_s_range = [[0., 0.], [-2e10, 2e10]],
    mas2_s_probs = [0.8, 0.2],
    
    # Other MAS-dependent parameters
    non_mas_p = 0.5,
    non_mas_m_trends = ["constant", "increase", "decrease"],
    non_mas_m_probs = [0.34, 0.33, 0.33],
    non_mas_m_range = [0., 1.],
    
    int_decrease_p = 0.1,
    int_decrease_scale =[0.3, 0.7],
    debug = False,
)

data_pars = dict(
    iso_pars = iso_pars,
    mas_pars = mas_pars,
    
    positive_iso = True,
    encode_imag = False, # Encode the imaginary part of the MAS spectra
    encode_wr = True, # Encode the MAS rate of the spectra

    # noise parameters
    noise = 0., # Noise level
    mas_l_noise = 0.05,
    mas_s_noise = 25.,
    
    smooth_end_len = 10, # Smooth ends of spectra
    iso_spec_norm = 40., # Normalization factor for peaks
    mas_spec_norm = 8., # Normalization factor for MAS spectra
    wr_norm_factor = 100_000.,
    wr_inv = False, # Encode inverse of MAS rate instead of MAS rate
    gen_mas_shifts = True,
)

model_pars = dict(
    input_dim = 2,
    n_models = 1,
    hidden_dim = [64, 64],
    kernel_size = [5, 5],
    num_layers = 2,
    batch_input = 1,
    bias = True,
    output_bias = True,
    return_all_layers = True,
    batch_norm = False,
    ndim = 2,
    independent = True,
    output_kernel_size = 5,
    output_act = "sigmoid",
    noise = 0.,
    invert = False,
)

loss_pars = dict(
    trg_fuzz=3.,
    trg_fuzz_len=25,
    ndim=2,
    exp=1.0,
    offset=1.0,
    factor=100.0,
    int_w=0.0,
    int_exp=2.0,
    return_components=False,
    device="cpu",
)

train_pars = dict(
    batch_size = 4,
    num_workers = 4,
    batches_per_epoch = 10,
    batches_per_eval = 5,
    n_epochs = 10,
    change_loss={3: {"trg_fuzz": 3.0, "factor": 10.},
                 6: {"trg_fuzz": 0.0, "factor": 0.},
                },
    out_dir = "../../data/2D/sanity_check/",
    device = "cuda" if torch.cuda.is_available() else "cpu",
    monitor_end = "\r"
)

fig_dir = "../../figures/2D/sanity_check/"
if not os.path.exists(fig_dir):
    os.mkdir(fig_dir)

# %%
with open("model_pars.json", "w") as F:
    json.dump(model_pars, F)

# %%
dataset = data.Dataset2D(params_x=data_pars, params_y=data_pars)

# %% [markdown]
# # Define network, loss and optimizer

# %%
net = model.ConvLSTMEnsemble(**model_pars)
loss = model.PIPLoss(**loss_pars)
opt = torch.optim.Adam(net.parameters(), lr=1e-3)
sch = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, factor=0.5, patience=50)

# %%
import importlib
importlib.reload(train)
# Out:
# <module 'pipnet.train' from '/Users/manuelcordova/Desktop/Work/PIP/PIPNet/src/pipnet/train.py'>

# %%
train.train(
    dataset,
    net,
    opt,
    loss,
    sch,
    **train_pars
)
# Out:
# Starting training...
# tensor(0.9827)
# tensor(0.9275)
# tensor(0.9866)
# tensor(0.9765)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9548)
# tensor(0.9783)
# tensor(0.8339)
# tensor(0.9352)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9978)
# tensor(0.9813)
# tensor(0.9887)
# tensor(0.9650)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9606)
# tensor(0.9988)
# tensor(0.9968)
# tensor(0.9728)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.8979)
# tensor(0.9810)
# tensor(0.9703)
# tensor(0.9822)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9746)
# tensor(0.9814)
# tensor(0.9752)
# tensor(0.9995)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9816)
# tensor(0.9670)
# tensor(0.9004)
# tensor(0.9638)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9824)
# tensor(0.9511)
# tensor(0.9953)
# tensor(0.9898)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9976)
# tensor(0.9633)
# tensor(0.9394)
# tensor(0.9558)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9940)
# tensor(0.9892)
# tensor(0.9817)
# tensor(1.2293)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9866)
# tensor(0.9511)
# tensor(0.8181)
# tensor(0.9880)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9693)
# tensor(0.9650)
# tensor(0.9436)
# tensor(0.9832)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9764)
# tensor(0.9938)
# tensor(0.9240)
# tensor(0.9920)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9122)
# tensor(0.9738)
# tensor(0.9825)
# tensor(0.9931)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9777)
# tensor(0.9128)
# tensor(0.9960)
# tensor(0.9626)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9554)
# tensor(0.9550)
# tensor(0.9608)
# tensor(0.9956)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9961)
# tensor(0.9730)
# tensor(0.9927)
# tensor(0.9670)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9845)
# tensor(0.9927)
# tensor(0.9689)
# tensor(0.9846)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9981)
# tensor(0.9893)
# tensor(0.9855)
# tensor(0.9570)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9883)
# tensor(0.9952)
# tensor(0.9703)
# tensor(0.9975)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9913)
# tensor(0.9600)
# tensor(0.9867)
# tensor(0.9386)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9635)
# tensor(0.9891)
# tensor(0.9912)
# tensor(0.9849)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9891)
# tensor(0.9696)
# tensor(0.9996)
# tensor(0.9838)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9773)
# tensor(0.9858)
# tensor(1.1554)
# tensor(0.9726)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9772)
# tensor(0.9978)
# tensor(1.5810)
# tensor(0.9759)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.8938)
# tensor(0.9825)
# tensor(0.9827)
# tensor(0.9433)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9148)
# tensor(0.9954)
# tensor(1.0941)
# tensor(0.9558)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9209)
# tensor(0.9608)
# tensor(0.8556)
# tensor(0.9663)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9640)
# tensor(0.9787)
# tensor(0.9345)
# tensor(0.9297)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9934)
# tensor(0.9554)
# tensor(0.8855)
# tensor(0.9165)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9796)
# tensor(0.9698)
# tensor(0.9812)
# tensor(1.0397)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9869)
# tensor(0.9729)
# tensor(0.9692)
# tensor(0.9176)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9723)
# tensor(0.9931)
# tensor(0.9980)
# tensor(0.9797)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9110)
# tensor(0.9695)
# tensor(0.9378)
# tensor(0.9601)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9754)
# tensor(0.9672)
# tensor(0.9537)
# tensor(0.9218)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9886)
# tensor(0.9938)
# tensor(0.9944)
# tensor(0.9981)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9823)
# tensor(0.9996)
# tensor(0.9970)
# tensor(0.9442)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9957)
# tensor(0.9927)
# tensor(0.8877)
# tensor(0.9636)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9808)
# tensor(1.0039)
# tensor(0.9741)
# tensor(0.8294)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9931)
# tensor(0.9536)
# tensor(0.9188)
# tensor(0.9784)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9877)
# tensor(0.9911)
# tensor(0.9786)
# tensor(0.9838)
# torch.Size([4, 12, 2, 128, 128])
# tensor(1.2838)
# tensor(0.9840)
# tensor(0.9348)
# tensor(0.9693)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9903)
# tensor(0.9860)
# tensor(0.9952)
# tensor(0.9959)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9216)
# tensor(0.9332)
# tensor(0.9956)
# tensor(0.9707)
# torch.Size([4, 12, 2, 128, 128])
# tensor(0.9814)
# tensor(0.9763)
# tensor(1.0642)
# tensor(0.9822)
# torch.Size([4, 12, 2, 128, 128])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 train.train(
#       2     dataset,
#       3     net,
#       4     opt,
#       5     loss,
#       6     sch,
#       7     **train_pars
#       8 )
#
# File ~/Desktop/Work/PIP/PIPNet/src/pipnet/train.py:142, in train(dataset, net, opt, loss, sch, batch_size, batches_per_epoch, batches_per_eval, n_epochs, avg_models, change_loss, out_dir, num_workers, device, monitor_end)
#     139 print("Starting training...")
#     141 # Training loop
# --> 142 for batch, (X, _, y) in enumerate(data_generator):
#     144     X = X.to(device)
#     145     y = y.to(device)
#
# File ~/opt/anaconda3/envs/PIPNet/lib/python3.9/site-packages/torch/utils/data/dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/opt/anaconda3/envs/PIPNet/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1359, in _MultiProcessingDataLoaderIter._next_data(self)
#    1356     return self._process_data(data)
#    1358 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1359 idx, data = self._get_data()
#    1360 self._tasks_outstanding -= 1
#    1361 if self._dataset_kind == _DatasetKind.Iterable:
#    1362     # Check for _IterableDatasetStopIteration
#
# File ~/opt/anaconda3/envs/PIPNet/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1325, in _MultiProcessingDataLoaderIter._get_data(self)
#    1321     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1322     # need to call `.task_done()` because we don't use `.join()`.
#    1323 else:
#    1324     while True:
# -> 1325         success, data = self._try_get_data()
#    1326         if success:
#    1327             return data
#
# File ~/opt/anaconda3/envs/PIPNet/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1163, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1150 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1151     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1152     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1160     # Returns a 2-tuple:
#    1161     #   (bool: whether successfully get data, any: data if successful else None)
#    1162     try:
# -> 1163         data = self._data_queue.get(timeout=timeout)
#    1164         return (True, data)
#    1165     except Exception as e:
#    1166         # At timeout and error, we manually check whether any worker has
#    1167         # failed. Note that this is the only mechanism for Windows to detect
#    1168         # worker failures.
#
# File ~/opt/anaconda3/envs/PIPNet/lib/python3.9/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/opt/anaconda3/envs/PIPNet/lib/python3.9/multiprocessing/connection.py:262, in _ConnectionBase.poll(self, timeout)
#     260 self._check_closed()
#     261 self._check_readable()
# --> 262 return self._poll(timeout)
#
# File ~/opt/anaconda3/envs/PIPNet/lib/python3.9/multiprocessing/connection.py:429, in Connection._poll(self, timeout)
#     428 def _poll(self, timeout):
# --> 429     r = wait([self], timeout)
#     430     return bool(r)
#
# File ~/opt/anaconda3/envs/PIPNet/lib/python3.9/multiprocessing/connection.py:936, in wait(object_list, timeout)
#     933     deadline = time.monotonic() + timeout
#     935 while True:
# --> 936     ready = selector.select(timeout)
#     937     if ready:
#     938         return [key.fileobj for (key, events) in ready]
#
# File ~/opt/anaconda3/envs/PIPNet/lib/python3.9/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
